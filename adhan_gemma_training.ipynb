# %% [markdown]
# # 🕌 ADHAN Gemma Training (GPU)
#
# This notebook automates the fine-tuning of the Adhan-Gemma model on a T4 GPU.
#
# ### 📝 Instructions:
# 1. Go to **Runtime** > **Change runtime type** > Select **T4 GPU**.
# 2. Run the cells below sequentially.

# %% [markdown]
# ## 1. Environment Setup

# %%
# Install dependencies
# !pip install -U torch transformers peft datasets accelerate bitsandbytes huggingface_hub python-dotenv

# Clone the repository (if not already present)
import os
if not os.path.exists('adhan'):
    # !git clone https://github.com/yazhi-lem/adhan.git

# %cd adhan
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Cloning into 'adhan'...
# remote: Enumerating objects: 4190, done.
# remote: Counting objects: 100% (338/338), done.
# remote: Compressing objects: 100% (255/255), done.
# remote: Total 4190 (delta 106), reused 271 (delta 72), pack-reused 3852 (from 2)
# Receiving objects: 100% (4190/4190), 110.49 MiB | 3.29 MiB/s, done.
# Resolving deltas: 100% (581/581), done.
# /home/zrya/Yazhi/Adhan/adhan/adhan

# %% [markdown]
# ## 2. Authentication
# You need a Hugging Face token to access the Gemma model.

# %%
from huggingface_hub import notebook_login
notebook_login()

# %% [markdown]
# ## 3. Run Training
# This runs the GPU-optimized script using the consolidated dataset.

# %%
# Set project root and run training
# %env ADHAN_PROJECT_ROOT=.
# !python src/gpu_lora_train.py

# %% [markdown]
# ## 4. Export & Download
# Once training is complete, run this to package the adapter for your local machine.

# %%
# !zip -r adhan-lora-adapter.zip models/adhan-gemma-v1-gpu/lora_adapter

from google.colab import files
files.download('adhan-lora-adapter.zip')
